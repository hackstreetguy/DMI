# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import numpy as np

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)


def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    mean = torch.mean(x)  # mean over all features (pixels) per sample
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %%
def create_semisupervised_setting(labels, normal_classes, outlier_classes, known_outlier_classes,ratio_known_normal, ratio_known_outlier, ratio_pollution):
    """
    Create a semi-supervised data setting. 
    :param labels: np.array with labels of all dataset samples
    :param normal_classes: tuple with normal class labels
    :param outlier_classes: tuple with anomaly class labels
    :param known_outlier_classes: tuple with known (labeled) anomaly class labels
    :param ratio_known_normal: the desired ratio of known (labeled) normal samples
    :param ratio_known_outlier: the desired ratio of known (labeled) anomalous samples
    :param ratio_pollution: the desired pollution ratio of the unlabeled data with unknown (unlabeled) anomalies.
    :return: tuple with list of sample indices, list of original labels, and list of semi-supervised labels
    """
    idx_normal = np.argwhere(np.isin(labels, normal_classes)).flatten()
    idx_outlier = np.argwhere(np.isin(labels, outlier_classes)).flatten()
    idx_known_outlier_candidates = np.argwhere(np.isin(labels, known_outlier_classes)).flatten()

    n_normal = len(idx_normal)

    # Solve system of linear equations to obtain respective number of samples
    a = np.array([[1, 1, 0, 0],
                  [(1-ratio_known_normal), -ratio_known_normal, -ratio_known_normal, -ratio_known_normal],
                  [-ratio_known_outlier, -ratio_known_outlier, -ratio_known_outlier, (1-ratio_known_outlier)],
                  [0, -ratio_pollution, (1-ratio_pollution), 0]])
    b = np.array([n_normal, 0, 0, 0])
    x = np.linalg.solve(a, b)

    # Get number of samples
    n_known_normal = int(x[0])
    n_unlabeled_normal = int(x[1])
    n_unlabeled_outlier = int(x[2])
    n_known_outlier = int(x[3])

    # Sample indices
    perm_normal = np.random.permutation(n_normal)
    perm_outlier = np.random.permutation(len(idx_outlier))
    perm_known_outlier = np.random.permutation(len(idx_known_outlier_candidates))

    idx_known_normal = idx_normal[perm_normal[:n_known_normal]].tolist()
    idx_unlabeled_normal = idx_normal[perm_normal[n_known_normal:n_known_normal+n_unlabeled_normal]].tolist()
    idx_unlabeled_outlier = idx_outlier[perm_outlier[:n_unlabeled_outlier]].tolist()
    idx_known_outlier = idx_known_outlier_candidates[perm_known_outlier[:n_known_outlier]].tolist()

    # Get original class labels
    labels_known_normal = labels[idx_known_normal].tolist()
    labels_unlabeled_normal = labels[idx_unlabeled_normal].tolist()
    labels_unlabeled_outlier = labels[idx_unlabeled_outlier].tolist()
    labels_known_outlier = labels[idx_known_outlier].tolist()

    # Get semi-supervised setting labels
    semi_labels_known_normal = np.ones(n_known_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_normal = np.zeros(n_unlabeled_normal).astype(np.int32).tolist()
    semi_labels_unlabeled_outlier = np.zeros(n_unlabeled_outlier).astype(np.int32).tolist()
    semi_labels_known_outlier = (-np.ones(n_known_outlier).astype(np.int32)).tolist()

    # Create final lists
    list_idx = idx_known_normal + idx_unlabeled_normal + idx_unlabeled_outlier + idx_known_outlier
    list_labels = labels_known_normal + labels_unlabeled_normal + labels_unlabeled_outlier + labels_known_outlier
    list_semi_labels = (semi_labels_known_normal + semi_labels_unlabeled_normal + semi_labels_unlabeled_outlier
                        + semi_labels_known_outlier)

    return list_idx, list_labels, list_semi_labels

# %%
from torchvision.datasets import MNIST
class MyMNIST(MNIST):
    """
    Torchvision MNIST class with additional targets for the semi-supervised setting and patch of __getitem__ method
    to also return the semi-supervised target as well as the index of a data sample.
    """

    def __init__(self, *args, **kwargs):
        super(MyMNIST, self).__init__(*args, **kwargs)

        self.semi_targets = torch.zeros_like(self.targets)

    def __getitem__(self, index):
        """Override the original method of the MNIST class.
        Args:
            index (int): Index

        Returns:
            tuple: (image, target, semi_target, index)
        """
        img, target, semi_target = self.data[index], int(self.targets[index]), int(self.semi_targets[index])

        # doing this so that it is consistent with all other datasets
        # to return a PIL Image
        img = Image.fromarray(img.numpy(), mode='L')

        if self.transform is not None:
            img = self.transform(img)

        if self.target_transform is not None:
            target = self.target_transform(target)

        return img, target, semi_target, index

# %%
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import Subset
from PIL import Image
# class MNIST_loader(data.Dataset):
#     """This class is needed to processing batches for the dataloader."""
#     def __init__(self, data, target, transform):
#         self.data = data
#         self.target = target
#         self.transform = transform
#         self.semi_targets = torch.zeros_like(self.targets)

#     def __getitem__(self, index):
#         """return transformed items."""
#         x = self.data[index]
#         y = self.target[index]
#         sy= self.semi_targets[index]
#         if self.transform:
#             x = Image.fromarray(x.numpy(), mode='L')
#             x = self.transform(x)
#         return x, y, sy

#     def __len__(self):
#         """number of samples."""
#         return len(self.data)


def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    """get dataloders"""
    n_classes = 2  # 0: normal, 1: outlier
    normal_classes = tuple([args.normal_class])
    outlier_classes = list(range(0, 10))
    outlier_classes.remove(args.normal_class)
    outlier_classes = tuple(outlier_classes)

    if args.n_known_outlier_classes == 0:
        known_outlier_classes = ()
    elif args.n_known_outlier_classes == 1:
        known_outlier_classes = tuple([args.known_outlier_class])
    else:
        known_outlier_classes = tuple(random.sample(outlier_classes, args.n_known_outlier_classes))
    
    transform = transforms.ToTensor()
    target_transform = transforms.Lambda(lambda x: int(x in outlier_classes))
    
    train = MyMNIST(root=data_dir, train=True,transform=transform, target_transform=target_transform,download=True)
    idx, _, semi_targets = create_semisupervised_setting(train.targets.cpu().data.numpy(), normal_classes,
                                                             outlier_classes, known_outlier_classes,
                                                             args.ratio_known_normal, args.ratio_known_outlier, args.ratio_pollution)
    train.semi_targets[idx] = torch.tensor(semi_targets)
    train = Subset(train, idx)          
    dataloader_train = DataLoader(train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    test = MyMNIST(root=data_dir, train=False, transform=transform, target_transform=target_transform,
                                download=True)
    dataloader_test = DataLoader(test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

# %%
# !pip install barbar
# Out:
# Requirement already satisfied: barbar in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
import torch.nn as nn
import torch.nn.functional as F
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)


class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat

# %%
from torch import optim
import torch.nn.functional as F

import numpy as np
from barbar import Bar



class TrainerDeepSAD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SAD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _, _, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSAD(ae, self.train_loader) 
    

    def save_weights_for_DeepSAD(self, model, dataloader):
        """Initialize Deep SAD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _, _, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SAD model"""
        net = network().to(self.device)
        eta=1
        eps=1e-6
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _, sy, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                sy=sy.float().to(self.device)
                optimizer.zero_grad()
                z = net(x)
                dist = torch.sum((z-c) ** 2, dim=1)
                losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
                loss = torch.mean(losses)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SAD... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

# %%
from sklearn.metrics import roc_auc_score


def eval(net, c, dataloader, device):
    """Testing the Deep SAD model"""

    scores = []
    labels = []
    epoch_loss=0
    nb=0
    eta=1.0
    eps=1e-6
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y, sy,_ in dataloader:
            x = x.float().to(device)
            y = y.float().to(device)
            sy= sy.float().to(device)
            z = net(x)
            dist = torch.sum((z-c) ** 2, dim=1)
            losses = torch.where(sy == 0, dist, eta * ((dist + eps) ** sy.float()))
            loss = torch.mean(losses)
            score=dist
            scores.append(score.detach().cpu())
            labels.append(y.cpu())
            epoch_loss+=loss
            nb+=1
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    print('mean loss: {:.2f}'.format(epoch_loss/nb))
    return labels, scores

# %%
class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass
    self.ratio_known_outlier=0.01
    self.ratio_known_normal=0.0
    self.ratio_pollution=0.1
    self.known_outlier_class=(nclass+1)%10
    self.n_known_outlier_classes=1

# %%
import matplotlib.pyplot as plt
import pandas as pd
nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SAD = TrainerDeepSAD(args, data, device)
  if args.pretrain:
      deep_SAD.pretrain()
  deep_SAD.train()
  print("test for calss  ",i,".....")
  labels, scores = eval(deep_SAD.net, deep_SAD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# 6647/6647: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 0, Loss: 147.785
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 113.872
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 91.974
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 78.638
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 70.576
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 65.136
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 61.131
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 57.878
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 55.108
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 52.667
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 50.216
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 47.730
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.532
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 43.286
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 41.252
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.258
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 37.396
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 35.718
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 34.201
# 6647/6647: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 32.789
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.414
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.181
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.115
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.090
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.077
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.068
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.061
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.057
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.055
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.051
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.049
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.048
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.046
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.045
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.043
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.043
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.041
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.040
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.039
# 6647/6647: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.039
# test for calss   0 .....
# Testing...
# ROC AUC score: 96.63
# mean loss: 0.12
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 176.555
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 135.145
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 101.738
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 78.587
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 63.564
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 53.831
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 47.011
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 41.984
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 38.200
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 35.320
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 33.012
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 31.190
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 29.686
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 28.427
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 27.379
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 26.464
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 25.636
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 24.871
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 24.187
# 7566/7566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 23.585
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.404
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.159
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.107
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.089
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.079
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.072
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.067
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.064
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.060
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.058
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.056
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.053
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.051
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.050
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.049
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.048
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.047
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.046
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.045
# 7566/7566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.044
# test for calss   1 .....
# Testing...
# ROC AUC score: 98.92
# mean loss: 0.14
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 178.639
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 146.294
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 118.452
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 95.691
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 80.684
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 70.955
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 64.523
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 59.936
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 56.469
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 53.741
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 51.508
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 49.658
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 48.074
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 46.711
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 45.518
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 44.449
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 43.520
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 42.656
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 41.904
# 6686/6686: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 41.205
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.526
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.249
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.170
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.138
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.120
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.107
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.098
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.092
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.087
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.082
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.078
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.075
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.071
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.069
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.067
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.065
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.063
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.062
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.060
# 6686/6686: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.060
# test for calss   2 .....
# Testing...
# ROC AUC score: 87.72
# mean loss: 0.11
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 139.123
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 106.177
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 85.588
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 73.379
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 65.344
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 59.814
# 6880/6880: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 55.870
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 52.876
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 50.381
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 48.354
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 46.740
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 45.362
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 44.210
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 43.222
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 42.327
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 41.552
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 40.837
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 40.157
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 39.566
# 6880/6880: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 39.032
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.554
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.234
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.150
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.117
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.099
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.088
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.082
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.077
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.075
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.072
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.068
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.065
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.063
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.063
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.061
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.059
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.057
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.057
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.055
# 6880/6880: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.056
# test for calss   3 .....
# Testing...
# ROC AUC score: 93.09
# mean loss: 0.13
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 138.958
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 106.288
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 85.089
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 72.028
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 63.834
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 58.323
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 54.373
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 51.324
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 48.761
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 46.531
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 44.658
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 43.095
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 41.777
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 40.613
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 39.589
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 38.676
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 37.861
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 37.102
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 36.424
# 6556/6556: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 35.788
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.555
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.243
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.154
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.123
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.106
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.096
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.088
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.082
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.078
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.073
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.069
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.066
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.063
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.061
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.059
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.057
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.055
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.053
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.052
# 6556/6556: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.051
# test for calss   4 .....
# Testing...
# ROC AUC score: 93.16
# mean loss: 0.13
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 154.675
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 124.190
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 100.720
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 84.136
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 73.312
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 66.099
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 60.880
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 56.914
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 53.661
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 50.949
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.758
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 46.907
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.290
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 43.899
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 42.674
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 41.561
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 40.587
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 39.719
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 38.878
# 6083/6083: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 38.113
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.955
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.380
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.197
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.147
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.123
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.110
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.102
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.094
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.089
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.086
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.082
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.078
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.075
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.074
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.071
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.068
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.066
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.064
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.062
# 6083/6083: [==============================>.] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.061
# test for calss   5 .....
# Testing...
# ROC AUC score: 81.82
# mean loss: 0.10
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 160.579
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 123.380
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 99.708
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 84.224
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 73.251
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 65.400
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 59.668
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 55.482
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 52.097
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 49.342
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 47.051
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.922
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 42.983
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 41.164
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 39.479
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 37.954
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 36.501
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 35.198
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 33.949
# 6641/6641: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 32.804
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.426
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.186
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.121
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.094
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.080
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.071
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.067
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.061
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.058
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.053
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.051
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.049
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.049
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.046
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.046
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.046
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.042
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.041
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.041
# 6641/6641: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.039
# test for calss   6 .....
# Testing...
# ROC AUC score: 97.16
# mean loss: 0.13
# 7031/7031: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 0, Loss: 170.550
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 131.402
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 101.729
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 82.179
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 69.107
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 60.357
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 54.345
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 50.096
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 46.749
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 44.176
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 42.060
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 40.210
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 38.600
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 37.407
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 36.331
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 35.493
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 34.670
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 33.947
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 33.248
# 7031/7031: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 32.755
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.562
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.251
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.159
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.125
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.109
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.101
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.090
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.084
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.079
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.076
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.072
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.069
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.067
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.064
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.063
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.062
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.060
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.058
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.058
# 7031/7031: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.055
# test for calss   7 .....
# Testing...
# ROC AUC score: 93.69
# mean loss: 0.12
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 150.814
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 119.156
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 94.878
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 78.324
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 68.113
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 61.626
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 57.221
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 54.052
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.650
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 49.769
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 48.242
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 46.954
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 45.852
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 44.910
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 44.094
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 43.386
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 42.754
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 42.210
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 41.713
# 6566/6566: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 41.242
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.549
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.270
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.181
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.144
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.125
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.113
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.104
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.100
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.093
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.089
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.085
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.082
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.080
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.077
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.076
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.073
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.072
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.070
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.068
# 6566/6566: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.067
# test for calss   8 .....
# Testing...
# ROC AUC score: 87.32
# mean loss: 0.12
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 184.104
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 146.450
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 119.462
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 96.230
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 79.063
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 67.907
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 60.478
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 55.284
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 51.466
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 48.544
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 46.239
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 44.362
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 42.810
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 41.505
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 40.379
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 39.393
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 38.566
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 37.751
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 36.961
# 6676/6676: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 36.324
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 0, Loss: 0.379
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 1, Loss: 0.178
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 2, Loss: 0.120
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 3, Loss: 0.098
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 4, Loss: 0.088
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 5, Loss: 0.079
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 6, Loss: 0.075
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 7, Loss: 0.068
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 8, Loss: 0.066
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 9, Loss: 0.064
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 10, Loss: 0.061
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 11, Loss: 0.059
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 12, Loss: 0.057
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 13, Loss: 0.056
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 14, Loss: 0.054
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 15, Loss: 0.053
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 16, Loss: 0.051
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 17, Loss: 0.050
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 18, Loss: 0.049
# 6676/6676: [===============================>] - ETA 0.1s
# Training Deep SAD... Epoch: 19, Loss: 0.049
# test for calss   9 .....
# Testing...
# ROC AUC score: 92.12
# mean loss: 0.11

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  96.62713244943211
# ROC scores for class  1  is:  98.92344044664088
# ROC scores for class  2  is:  87.7178341683436
# ROC scores for class  3  is:  93.09077192480093
# ROC scores for class  4  is:  93.1613125864135
# ROC scores for class  5  is:  81.8212405296876
# ROC scores for class  6  is:  97.16016742097537
# ROC scores for class  7  is:  93.69246041727745
# ROC scores for class  8  is:  87.31854269049806
# ROC scores for class  9  is:  92.11570341401858

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for calss '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
