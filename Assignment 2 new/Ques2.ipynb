# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import numpy as np

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)


def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    mean = torch.mean(x)  # mean over all features (pixels) per sample
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %%
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from PIL import Image
class MNIST_loader(data.Dataset):
    """This class is needed to processing batches for the dataloader."""
    def __init__(self, data, target, transform):
        self.data = data
        self.target = target
        self.transform = transform

    def __getitem__(self, index):
        """return transformed items."""
        x = self.data[index]
        y = self.target[index]
        if self.transform:
            x = Image.fromarray(x.numpy(), mode='L')
            x = self.transform(x)
        return x, y

    def __len__(self):
        """number of samples."""
        return len(self.data)


def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    """get dataloders"""
    # min, max values for each class after applying GCN (as the original implementation)
    min_max = [(-0.8826567065619495, 9.001545489292527),
                (-0.6661464580883915, 20.108062262467364),
                (-0.7820454743183202, 11.665100841080346),
                (-0.7645772083211267, 12.895051191467457),
                (-0.7253923114302238, 12.683235701611533),
                (-0.7698501867861425, 13.103278415430502),
                (-0.778418217980696, 10.457837397569108),
                (-0.7129780970522351, 12.057777597673047),
                (-0.8280402650205075, 10.581538445782988),
                (-0.7369959242164307, 10.697039838804978)]

    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Lambda(lambda x: global_contrast_normalization(x)),
                                    transforms.Normalize([min_max[args.normal_class][0]],
                                                         [min_max[args.normal_class][1] \
                                                         -min_max[args.normal_class][0]])])
    train = datasets.MNIST(root=data_dir, train=True, download=True)
    test = datasets.MNIST(root=data_dir, train=False, download=True)

    x_train = train.data
    y_train = train.targets

    x_train = x_train[np.where(y_train==args.normal_class)]
    y_train = y_train[np.where(y_train==args.normal_class)]
                                    
    data_train = MNIST_loader(x_train, y_train, transform)
    dataloader_train = DataLoader(data_train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    x_test = test.data
    y_test = test.targets
    y_test = np.where(y_test==args.normal_class, 0, 1)
    data_test = MNIST_loader(x_test, y_test, transform)
    dataloader_test = DataLoader(data_test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

# %%
# !pip install barbar
# Out:
# Collecting barbar
#   Downloading https://files.pythonhosted.org/packages/48/1f/9b69ce144f484cfa00feb09fa752139658961de6303ea592487738d0b53c/barbar-0.2.1-py3-none-any.whl
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1

# %%
import torch.nn as nn
import torch.nn.functional as F
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)


class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat

# %%
from torch import optim
import torch.nn.functional as F

import numpy as np
from barbar import Bar



class TrainerDeepSVDD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SVDD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSVDD(ae, self.train_loader) 
    

    def save_weights_for_DeepSVDD(self, model, dataloader):
        """Initialize Deep SVDD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SVDD model"""
        net = network().to(self.device)
        
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)

                optimizer.zero_grad()
                z = net(x)
                loss = torch.mean(torch.sum((z - c) ** 2, dim=1))
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SVDD... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

# %%
from sklearn.metrics import roc_auc_score


def eval(net, c, dataloader, device):
    """Testing the Deep SVDD model"""

    scores = []
    labels = []
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y in dataloader:
            x = x.float().to(device)
            z = net(x)
            score = torch.sum((z - c) ** 2, dim=1)

            scores.append(score.detach().cpu())
            labels.append(y.cpu())
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    return labels, scores

# %%
class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass

# %%
import matplotlib.pyplot as plt
import pandas as pd
nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SVDD = TrainerDeepSVDD(args, data, device)
  if args.pretrain:
      deep_SVDD.pretrain()
  deep_SVDD.train()
  print("test for class  ",i,".....")
  labels, scores = eval(deep_SVDD.net, deep_SVDD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting /content/drive/MyDrive/Data/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting /content/drive/MyDrive/Data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting /content/drive/MyDrive/Data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting /content/drive/MyDrive/Data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/Data/MNIST/raw
# Processing...
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:479: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
# 5923/5923: [==============================>.] - ETA 0.5s
# Pretraining Autoencoder... Epoch: 0, Loss: 126.492
# 5923/5923: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 93.262
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 69.389
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 52.324
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 40.507
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 32.365
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 26.624
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 22.501
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 19.457
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 17.154
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.329
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.903
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.753
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.808
# 5923/5923: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.020
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.331
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.742
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.223
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.770
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.370
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.213
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.079
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.042
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.028
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.022
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.018
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.016
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.014
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.013
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.013
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.010
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.009
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.008
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.008
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   0 .....
# Testing...
# ROC AUC score: 95.74
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 127.791
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 89.404
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 63.064
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 45.792
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 34.658
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 27.283
# 6742/6742: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 22.179
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 18.524
# 6742/6742: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 8, Loss: 15.819
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 13.760
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 12.144
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 10.843
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 9.775
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 8.883
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 8.120
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 7.468
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 6.903
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 6.408
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 5.973
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 5.584
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.072
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.018
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.009
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.007
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.006
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.002
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.002
# test for calss   1 .....
# Testing...
# ROC AUC score: 99.55
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 156.427
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 118.497
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 88.558
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 66.210
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 50.557
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 39.845
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 32.370
# 5958/5958: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 7, Loss: 26.979
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 23.003
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 20.018
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.730
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 15.938
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.502
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.332
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.369
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.566
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.882
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.299
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.795
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.349
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.176
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.078
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.046
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.032
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.024
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.020
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.017
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.015
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.013
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.013
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.012
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.011
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.010
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.009
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.009
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.008
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.008
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.008
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   2 .....
# Testing...
# ROC AUC score: 87.62
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 128.394
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 93.746
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 67.918
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 49.840
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 38.082
# 6131/6131: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 5, Loss: 30.240
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 24.832
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 20.972
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.118
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 15.947
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.247
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 12.881
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 11.783
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 10.881
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.133
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 9.499
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 8.962
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 8.488
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.079
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 7.719
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.140
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.057
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.036
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.027
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.022
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.019
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.016
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.015
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.014
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.012
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.010
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.009
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.009
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.009
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.008
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   3 .....
# Testing...
# ROC AUC score: 92.33
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 157.424
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 121.319
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 92.647
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 69.219
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 52.197
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 40.532
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 32.579
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 27.079
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 23.094
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 20.103
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.837
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 16.040
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.597
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.426
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.458
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.628
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.924
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.323
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.768
# 5842/5842: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.282
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.186
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.072
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.043
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.033
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.027
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.023
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.020
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.018
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.016
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.015
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.014
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.013
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.011
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.008
# test for calss   4 .....
# Testing...
# ROC AUC score: 95.21
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 144.029
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 111.732
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 85.060
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 64.266
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 49.363
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 39.205
# 5421/5421: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 32.146
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 27.075
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 23.307
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 20.481
# 5421/5421: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 10, Loss: 18.227
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 16.451
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.972
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.803
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.820
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.949
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.237
# 5421/5421: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.610
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.079
# 5421/5421: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.567
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.589
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.194
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.103
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.074
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.059
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.049
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.045
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.037
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.034
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.031
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.028
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.029
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.027
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.023
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.023
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.020
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.020
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.018
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.018
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.017
# test for calss   5 .....
# Testing...
# ROC AUC score: 85.20
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 0, Loss: 146.755
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 110.041
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 81.944
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 61.774
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 47.699
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 37.941
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 31.143
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 7, Loss: 26.277
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 22.684
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 9, Loss: 19.945
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.847
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 11, Loss: 16.192
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.844
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.735
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.804
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 15, Loss: 12.022
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.345
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.745
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.214
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.726
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.221
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.078
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.039
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.026
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.019
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.016
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.014
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.013
# 5918/5918: [==============================>.] - ETA 0.2s
# Training Deep SVDD... Epoch: 8, Loss: 0.010
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.010
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.009
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.008
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.008
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.007
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.007
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.006
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.006
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.006
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.005
# test for calss   6 .....
# Testing...
# ROC AUC score: 97.98
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 0, Loss: 140.736
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 102.585
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 74.732
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 3, Loss: 55.918
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 4, Loss: 43.022
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 5, Loss: 34.306
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 28.259
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 7, Loss: 23.861
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 8, Loss: 20.602
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 9, Loss: 18.120
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 16.232
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.761
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.561
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.570
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.744
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.032
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.413
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.872
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.389
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.953
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.213
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.085
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.047
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.031
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.024
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.019
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.016
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.014
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.012
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.011
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.009
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.009
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.008
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.006
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.006
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.006
# test for calss   7 .....
# Testing...
# ROC AUC score: 93.81
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 128.978
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 94.607
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 2, Loss: 69.880
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 3, Loss: 52.343
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 4, Loss: 40.138
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 5, Loss: 31.871
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 26.195
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 7, Loss: 22.169
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 19.196
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.945
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.221
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.881
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.804
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.919
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.182
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.543
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.010
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.542
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.147
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.798
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.091
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.043
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.026
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.018
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.014
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.011
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.010
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.008
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.005
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.005
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.004
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.004
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.004
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.004
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.004
# test for calss   8 .....
# Testing...
# ROC AUC score: 92.53
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 163.349
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 127.076
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 2, Loss: 97.100
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 3, Loss: 73.281
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 56.296
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 44.729
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 36.522
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 30.545
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 26.230
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 23.005
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 10, Loss: 20.510
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 18.526
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 16.929
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 15.619
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 14.544
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 13.640
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 16, Loss: 12.851
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 12.152
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 11.539
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 11.004
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.271
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.108
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.061
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.042
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.032
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.026
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.021
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.018
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.016
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.014
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.013
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.012
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.009
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.009
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.008
# test for calss   9 .....
# Testing...
# ROC AUC score: 94.24

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  95.74265803882528
# ROC scores for class  1  is:  99.55272305333801
# ROC scores for class  2  is:  87.62167508592134
# ROC scores for class  3  is:  92.32771286027378
# ROC scores for class  4  is:  95.20991960410477
# ROC scores for class  5  is:  85.19595939902041
# ROC scores for class  6  is:  97.9786974171565
# ROC scores for class  7  is:  93.81319921381001
# ROC scores for class  8  is:  92.52513045816535
# ROC scores for class  9  is:  94.2430923380158

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for calss '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
